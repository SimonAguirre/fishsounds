# %%
import pandas as pd
from glob import glob
import librosa
import librosa.display
import matplotlib.pyplot as  plt
import numpy as np
from IPython.display import Audio
from IPython.core.display import display
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_27704\459144925.py:8: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
import matplotlib.pyplot as  plt

# %%
f_names = glob("denoised-segmented\*.wav")

# %%
metadata = pd.DataFrame({'file_names':f_names})

# %%
metadata.rename(columns = {'test':'TEST'}, inplace = True)

# %%
metadata["file_names"] = metadata["file_names"].apply(lambda x: x[19:])

# %%
output_dir = "metadata"

# %%
# metadata["ClassId"][0]
metadata["Class"].iloc[0] = "hi"
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_27704\1137687858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata["Class"].iloc[0] = "hi"

# %%
metadata
# Out:
#                                             file_names  ClassID Class
# 0    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0    hi
# 1    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0  None
# 2    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0  None
# 3    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Sea...        0  None
# 4    1407,3005_HawkinsT-1978_Pollachius-pollachius_...        0  None
# ..                                                 ...      ...   ...
# 389  817,883,etc_HawkinsT-2002_Melanogrammus-aeglef...        0  None
# 390  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0  None
# 391  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0  None
# 392  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0  None
# 393  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0  None
#
# [394 rows x 3 columns]

# %%
index = 0
while (1):
    f_name = metadata["file_names"].iloc[index]
    signal, rate = librosa.load("denoised-segmented/"+f_name)    
    fig, ax = plt.subplots(2,1, figsize=(10,4))
    plt.subplots_adjust(hspace=0.5)

    # Wave form
    ax[0].set(title=f_name)
    ax[0].plot(signal, lw=1)
    ax[0].set_ylabel("Waveform")
    ax[0].set_ylim(-1,1)
    fig.colorbar(melspec_img, ax=ax[0])

    # Melspectrogram
    S = librosa.feature.melspectrogram(y=signal, sr=rate, n_mels=128, fmax=8000)
    S_dB = librosa.power_to_db(S, ref=np.max)
    melspec_img = librosa.display.specshow(S_dB, x_axis='time',
                         y_axis='mel', sr=rate,
                         fmax=8000, ax=ax[1])
    fig.colorbar(melspec_img, ax=ax[1], format='%+2.0f dB')
    ax[1].set_ylim(0,1250)
    ax[1].set_xlabel(None)
    ax[1].set_ylabel("Melspectrogram")
    plt.show()

    display(Audio(filename = f"denoised-segmented/{f_name}", rate=rate))
    print("Current File : "+f_name)
    print("Current Class : "+metadata["Class"].iloc[index])
    print("Current Index : "+str(index))
    class_name = input()
    if (class_name == "stop"):
        break
    elif (class_name == "next"):
        index += 1
        continue
    elif (class_name == "prev"):
        index += -1
        continue
    else:
        metadata["Class"].iloc[index] = class_name
        index += 1
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Current File : 1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aquarium_event_0.wav
# Current Class : grunt
# Current Index : 0

# %%
metadata
# Out:
#                                             file_names  ClassID    Class
# 0    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0    grunt
# 1    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0    grunt
# 2    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...        0    grunt
# 3    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Sea...        0  invalid
# 4    1407,3005_HawkinsT-1978_Pollachius-pollachius_...        0     None
# ..                                                 ...      ...      ...
# 389  817,883,etc_HawkinsT-2002_Melanogrammus-aeglef...        0     None
# 390  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0     None
# 391  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0     None
# 392  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0     None
# 393  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...        0     None
#
# [394 rows x 3 columns]

# %%
metadata
# Out:
#                                             file_names
# 0    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...
# 1    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...
# 2    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Aqu...
# 3    1407,3005_HawkinsT-1978_Gadus-morhua_Grunt_Sea...
# 4    1407,3005_HawkinsT-1978_Pollachius-pollachius_...
# ..                                                 ...
# 389  817,883,etc_HawkinsT-2002_Melanogrammus-aeglef...
# 390  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...
# 391  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...
# 392  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...
# 393  884_AmorimC-2000_Trigloporus-lastoviza_Growl_e...
#
# [394 rows x 1 columns]
